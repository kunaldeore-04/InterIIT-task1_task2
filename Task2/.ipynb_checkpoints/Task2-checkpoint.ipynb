# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
import joblib
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input, BatchNormalization, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight
import tensorflow.keras.backend as K

# %%
df = pd.read_csv('bitcoin_2020-10-23_2025-10-22.csv')

# %%
# Trim the dataframe to include only required columns
columns_to_keep = ['End', 'Close', 'Open', 'High', 'Low', 'Volume']
df = df[columns_to_keep].copy()

# %%
# Convert to date and clean data
df['Date'] = pd.to_datetime(df['End'], errors='coerce')
df = df.dropna(subset=['Date'])
df = df.sort_values('Date')
df.set_index('Date', inplace=True)
df.shape #number of columns before adding features: 6
# Out:
# (1825, 6)

# %%
# Visualize closing price
plt.figure(figsize=(14, 7))
plt.title('Bitcoin Close Price Over Time')
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
#Add custom features
df['Returns'] = df['Close'].pct_change()
df['MA_7'] = df['Close'].rolling(window=7).mean()
df['MA_21'] = df['Close'].rolling(window=21).mean()
df['MA_50'] = df['Close'].rolling(window=50).mean()
df['MA_Cross'] = df['MA_7'] - df['MA_21']
df['Volatility_7'] = df['Returns'].rolling(window=7).std()
df['Volatility_21'] = df['Returns'].rolling(window=21).std()
df['Momentum_5'] = df['Close'] - df['Close'].shift(5)
df['Momentum_10'] = df['Close'] - df['Close'].shift(10)
df['Volume_MA'] = df['Volume'].rolling(window=20).mean()
df['Volume_Ratio'] = df['Volume'] / (df['Volume_MA'] + 1e-10)
df['Price_Range'] = (df['High'] - df['Low']) / df['Close']
df['High_Low_Pct'] = (df['High'] - df['Low']) / df['Low']
df['Target_price'] = df['Close'].shift(-1) #this is not a input column this what model is expected to predict
df = df.dropna()
df.columns #number of columns now :20 ,Also few rows dropped
# Out:
# Index(['End', 'Close', 'Open', 'High', 'Low', 'Volume', 'Returns', 'MA_7',
#        'MA_21', 'MA_50', 'MA_Cross', 'Volatility_7', 'Volatility_21',
#        'Momentum_5', 'Momentum_10', 'Volume_MA', 'Volume_Ratio', 'Price_Range',
#        'High_Low_Pct', 'Target_price'],
#       dtype='object')

# %%
feature_columns = [
    'Open', 'High', 'Low', 'Close', 'Volume',
    'Returns',
    'MA_7', 'MA_21', 'MA_50', 'MA_Cross',
    'Volatility_7', 'Volatility_21',
    'Momentum_5', 'Momentum_10',
    'Volume_Ratio', 'Price_Range', 'High_Low_Pct',
]
features = df[feature_columns].values
target_price = df['Target_price'].values

# %%
#creating sequences for LSTM

SEQUENCE_LENGTH = 30

def create_sequences(features, target, seq_n):
    x, y = [], []
    for i in range(seq_n - 1, len(features)):
        x.append(features[i-(seq_n-1):i+1, :]) 
        y.append(target[i])
    return np.array(x), np.array(y)

# %%
#train test split
train_n = int(np.ceil(len(features) * 0.8))
scaler = RobustScaler()
scaler.fit(features[0:train_n])
scaled_features = scaler.transform(features)
X, y = create_sequences(scaled_features, target_price, SEQUENCE_LENGTH)
joblib.dump(scaler, 'scaler_robust.joblib')
split_idx = train_n - (SEQUENCE_LENGTH - 1)
x_train = X[0:split_idx]
y_train = y[0:split_idx]
x_test = X[split_idx:]
y_test = y[split_idx:]

# %%
#Model Architechture

input_shape = (x_train.shape[1], x_train.shape[2])
model = Sequential([
    Input(shape=input_shape),
    
    Bidirectional(LSTM(64, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.3),
    
    Bidirectional(LSTM(32, return_sequences=False)),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mean_absolute_error']
)

# %%
# after frying my laptop with 200 epoch I had to use early stopping ....reduce_lr is standard ( i think so)

early_stop = EarlyStopping( 
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=0.00001,
    verbose=1
)

# %%
#training the model
history = model.fit(
    x_train, y_train,
    batch_size=32,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 1892307840.0000 - mean_absolute_error: 40481.0430 - val_loss: 10419059712.0000 - val_mean_absolute_error: 101352.1328 - learning_rate: 0.0010
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1891233792.0000 - mean_absolute_error: 40470.7227 - val_loss: 10410896384.0000 - val_mean_absolute_error: 101311.8672 - learning_rate: 0.0010
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1886390144.0000 - mean_absolute_error: 40423.2422 - val_loss: 10374045696.0000 - val_mean_absolute_error: 101129.9062 - learning_rate: 0.0010
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1871438080.0000 - mean_absolute_error: 40279.6367 - val_loss: 10277841920.0000 - val_mean_absolute_error: 100653.3516 - learning_rate: 0.0010
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1837938304.0000 - mean_absolute_error: 39942.9336 - val_loss: 10084491264.0000 - val_mean_absolute_error: 99689.4219 - learning_rate: 0.0010
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1774146688.0000 - mean_absolute_error: 39311.2930 - val_loss: 9734659072.0000 - val_mean_absolute_error: 97919.3203 - learning_rate: 0.0010
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1674021248.0000 - mean_absolute_error: 38195.6016 - val_loss: 9241670656.0000 - val_mean_absolute_error: 95371.2656 - learning_rate: 0.0010
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1518602496.0000 - mean_absolute_error: 36383.2305 - val_loss: 8488622080.0000 - val_mean_absolute_error: 91339.1953 - learning_rate: 0.0010
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1304077184.0000 - mean_absolute_error: 33844.5195 - val_loss: 7532330496.0000 - val_mean_absolute_error: 85943.9688 - learning_rate: 0.0010
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1069721344.0000 - mean_absolute_error: 30771.3926 - val_loss: 6464160256.0000 - val_mean_absolute_error: 79503.5625 - learning_rate: 0.0010
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 790329088.0000 - mean_absolute_error: 26216.2129 - val_loss: 5283789824.0000 - val_mean_absolute_error: 71704.9453 - learning_rate: 0.0010
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 574023616.0000 - mean_absolute_error: 22285.4238 - val_loss: 4105853184.0000 - val_mean_absolute_error: 62955.4375 - learning_rate: 0.0010
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 349930208.0000 - mean_absolute_error: 16532.7676 - val_loss: 3214055936.0000 - val_mean_absolute_error: 55450.6758 - learning_rate: 0.0010
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 249419088.0000 - mean_absolute_error: 13261.5303 - val_loss: 2411785984.0000 - val_mean_absolute_error: 47670.6094 - learning_rate: 0.0010
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 171283392.0000 - mean_absolute_error: 10485.0127 - val_loss: 1943075072.0000 - val_mean_absolute_error: 42491.3047 - learning_rate: 0.0010
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 147223744.0000 - mean_absolute_error: 9565.7100 - val_loss: 1682949376.0000 - val_mean_absolute_error: 39302.6211 - learning_rate: 0.0010
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 123228128.0000 - mean_absolute_error: 8707.6885 - val_loss: 1555195520.0000 - val_mean_absolute_error: 38041.5742 - learning_rate: 0.0010
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 124938752.0000 - mean_absolute_error: 8787.8926 - val_loss: 1350594176.0000 - val_mean_absolute_error: 35088.2383 - learning_rate: 0.0010
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 130131536.0000 - mean_absolute_error: 8981.2715 - val_loss: 1212381440.0000 - val_mean_absolute_error: 33037.8320 - learning_rate: 0.0010
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 125281168.0000 - mean_absolute_error: 8734.9111 - val_loss: 1220604288.0000 - val_mean_absolute_error: 33094.0078 - learning_rate: 0.0010
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 131862168.0000 - mean_absolute_error: 9127.4482 - val_loss: 1277544192.0000 - val_mean_absolute_error: 33893.7617 - learning_rate: 0.0010
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 136366816.0000 - mean_absolute_error: 9332.3018 - val_loss: 1344537088.0000 - val_mean_absolute_error: 34815.5234 - learning_rate: 0.0010
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 120155864.0000 - mean_absolute_error: 8612.4893 - val_loss: 1321361408.0000 - val_mean_absolute_error: 34483.6406 - learning_rate: 0.0010
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 128277664.0000 - mean_absolute_error: 8876.4727 - val_loss: 1263133440.0000 - val_mean_absolute_error: 33573.7422 - learning_rate: 0.0010
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 127941640.0000 - mean_absolute_error: 8937.8545 - val_loss: 1288597760.0000 - val_mean_absolute_error: 33950.8203 - learning_rate: 0.0010
# Epoch 26/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 120472600.0000 - mean_absolute_error: 8631.3125
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 139004768.0000 - mean_absolute_error: 9284.7334 - val_loss: 1418550016.0000 - val_mean_absolute_error: 35798.6953 - learning_rate: 0.0010
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 123827536.0000 - mean_absolute_error: 8654.3447 - val_loss: 1423141504.0000 - val_mean_absolute_error: 35864.3945 - learning_rate: 5.0000e-04
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 131154376.0000 - mean_absolute_error: 9062.0889 - val_loss: 1351539840.0000 - val_mean_absolute_error: 34860.6055 - learning_rate: 5.0000e-04
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 131607584.0000 - mean_absolute_error: 8992.8369 - val_loss: 1333152128.0000 - val_mean_absolute_error: 34584.8203 - learning_rate: 5.0000e-04
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 121230296.0000 - mean_absolute_error: 8747.2842 - val_loss: 1350679296.0000 - val_mean_absolute_error: 34825.8906 - learning_rate: 5.0000e-04
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 131747904.0000 - mean_absolute_error: 9009.5215 - val_loss: 1323526400.0000 - val_mean_absolute_error: 34454.7656 - learning_rate: 5.0000e-04
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 123466984.0000 - mean_absolute_error: 8644.2168 - val_loss: 1303838720.0000 - val_mean_absolute_error: 34159.5195 - learning_rate: 5.0000e-04
# Epoch 33/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 121676104.0000 - mean_absolute_error: 8441.3027
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 121846664.0000 - mean_absolute_error: 8488.5664 - val_loss: 1302676992.0000 - val_mean_absolute_error: 34150.4414 - learning_rate: 5.0000e-04
# Epoch 34/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 119781752.0000 - mean_absolute_error: 8512.2549 - val_loss: 1296890752.0000 - val_mean_absolute_error: 34067.9922 - learning_rate: 2.5000e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,accuracy_score

predicted_prices = model.predict(x_test)
predicted_prices_flat = predicted_prices.flatten()
test_dates = df.index[train_n:]

mae = mean_absolute_error(y_test, predicted_prices)
mse = mean_squared_error(y_test, predicted_prices)
r2 = r2_score(y_test, predicted_prices)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R-squared (R2): {r2:.4f}")
previous_actual_prices = y_test[:-1]
current_actual_prices = y_test[1:]
current_predicted_prices = predicted_prices_flat[1:]
actual_moves = (current_actual_prices > previous_actual_prices).astype(int)
predicted_moves = (current_predicted_prices > previous_actual_prices).astype(int)
directional_accuracy = accuracy_score(actual_moves, predicted_moves)
print(f"Directional Accuracy: {directional_accuracy * 100:.2f}%")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Mean Absolute Error (MAE): 33037.8326
# Mean Squared Error (MSE): 1212381374.7538
# R-squared (R2): -7.2584
# Directional Accuracy: 48.59%

# %%
plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test, label='Actual Price', color='blue') # y_test now holds actual prices
plt.plot(test_dates, predicted_prices, label='Predicted Price', color='red', linestyle='--')
plt.title('Bitcoin Price: Actual vs. Predicted (Regression)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
#Market simulation
actual_prices = df['Close'].values[train_n:]

initial_capital = 10000
capital = initial_capital
position = 0  # 0 = no position, 1 = holding bitcoin
btc_amount = 0 
entry_price = 0
trades = []
portfolio_value = []

# %%
predicted_directions = []
if len(predicted_prices) > 0 and len(actual_prices) > 0:
    # Use the first actual price as the base for the first prediction
    predicted_directions.append(1 if predicted_prices[0][0] > actual_prices[0] else 0)
    # For subsequent predictions, compare with the previous day's actual price
    for i in range(len(predicted_prices) - 1):
        predicted_directions.append(1 if predicted_prices[i+1][0] > actual_prices[i] else 0)
else:
    print("Warning: predicted_prices or actual_prices is empty.")
for i in range(len(predicted_directions)):
    current_price = actual_prices[i]
    signal = predicted_directions[i] # Use the generated directional signal

    # Buy signal: Predict Up (1) and currently not holding (position == 0)
    if signal == 1 and position == 0:
        position = 1
        entry_price = current_price
        btc_amount = capital / current_price # Calculate amount based on current capital
        capital = 0 # Capital is now in BTC
        trades.append(('BUY', test_dates[i], current_price, btc_amount * entry_price)) # Log value at time of trade
        # print(f"Buying at {current_price}") # Optional print statement

    # Sell signal: Predict Down (0) and currently holding (position == 1)
    elif signal == 0 and position == 1:
        position = 0
        capital = btc_amount * current_price # Calculate capital based on current price
        profit = capital - (btc_amount * entry_price) # Calculate profit based on entry
        trades.append(('SELL', test_dates[i], current_price, capital)) # Log value at time of trade
        btc_amount = 0 # Reset BTC amount
        entry_price = 0 # Reset entry price
        # print(f"Selling at {current_price}") # Optional print statement

    # Calculate current portfolio value for the day
    if position == 1:
        current_value = btc_amount * current_price # Value is BTC amount * current price
    else:
        current_value = capital # Value is the cash capital held

    portfolio_value.append(current_value)

# If still holding Bitcoin at the end of the simulation period, sell at the last known price
if position == 1:
    final_sell_price = actual_prices[-1]
    capital = btc_amount * final_sell_price
    trades.append(('SELL', test_dates[-1], final_sell_price, capital))
    position = 0 # Update position state
    # Update the last portfolio value entry
    if portfolio_value:
         portfolio_value[-1] = capital


# --- Calculate Final Results ---
final_capital = capital # Final capital is the cash held after the loop (and potential final sell)
total_return = ((final_capital - initial_capital) / initial_capital) * 100 if initial_capital > 0 else 0

# --- Print Results (Example - you might have this later) ---
print(f"Initial Capital: ${initial_capital:,.2f}")
print(f"Final Capital: ${final_capital:,.2f}")
print(f"Total Return: {total_return:.2f}%")
print(f"Number of Buys: {len([t for t in trades if t[0] == 'BUY'])}")
print(f"Number of Sells: {len([t for t in trades if t[0] == 'SELL'])}")
# Out:
# Initial Capital: $10,000.00
# Final Capital: $10,000.00
# Total Return: 0.00%
# Number of Buys: 0
# Number of Sells: 0

# %%
#buy and hold strategy
buy_hold_btc = initial_capital / actual_prices[0]
buy_hold_final = buy_hold_btc * actual_prices[-1]
buy_hold_return = ((buy_hold_final - initial_capital) / initial_capital) * 100

# %%
    print(f"\nInitial Capital: ${initial_capital:,.2f}")
    print(f"Final Capital: ${final_capital:,.2f}")
    print(f"Total Return: {total_return:.2f}%")
    print(f"\nBuy & Hold Strategy:")
    print(f"Final Value: ${buy_hold_final:,.2f}")
    print(f"Total Return: {buy_hold_return:.2f}%")
    print(f"\nNumber of Trades: {len([t for t in trades if t[0] == 'BUY'])}")
# Out:
# Initial Capital: $10,000.00
# Final Capital: $10,000.00
# Total Return: 0.00%
#
# Buy & Hold Strategy:
# Final Value: $15,717.37
# Total Return: 57.17%
#
# Number of Trades: 0

# %%
# === VISUALIZATION OF RESULTS ===

print("\n" + "="*60)
print("FINAL METRICS & VISUALIZATION")
print("="*60)

# 1. Print the Accuracy Score (which you already calculated)
print(f"Directional Accuracy (using optimal threshold): {accuracy * 100:.4f}%")
print(f"ROC AUC Score: {roc_auc:.4f}")

# 2. Create the plots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12), gridspec_kw={'height_ratios': [2, 1]})

# === PLOT 1: Actual Price vs. Predicted Signals ===
ax1.plot(test_dates, actual_prices, label='Actual Price (Test Set)', color='blue', linewidth=2)
ax1.set_xlabel('Date')
ax1.set_ylabel('Price (USD)', color='blue')
ax1.set_title('Bitcoin Price with Model Predictions')
ax1.legend(loc='upper left')
ax1.grid(True, alpha=0.3)

# Create a second y-axis to show signals clearly
ax1_twin = ax1.twinx()

# Flatten predictions array for easier processing
flat_predictions = predictions.flatten()

# Find the indices for buy and sell signals
buy_signals = [i for i, p in enumerate(flat_predictions) if p == 1]
sell_signals = [i for i, p in enumerate(flat_predictions) if p == 0]

# Plot signals as markers on the price chart
ax1_twin.scatter([test_dates[i] for i in buy_signals], 
                 [actual_prices[i] for i in buy_signals], 
                 color='green', marker='^', s=100, alpha=0.7, label='Buy Signal (Predict Up)')
ax1_twin.scatter([test_dates[i] for i in sell_signals], 
                 [actual_prices[i] for i in sell_signals], 
                 color='red', marker='v', s=100, alpha=0.7, label='Sell Signal (Predict Down)')

# We don't need a separate y-axis label for the twin, just the legend
ax1_twin.set_yticks([]) 
ax1_twin.legend(loc='upper right')

# === PLOT 2: Portfolio Value vs. Buy & Hold ===

# Calculate the Buy & Hold portfolio value over time for the plot
buy_hold_value_over_time = (initial_capital / actual_prices[0]) * actual_prices

ax2.plot(test_dates, portfolio_value, label=f'Model Strategy ({total_return:,.2f}%)', 
         color='green', linewidth=2)
ax2.plot(test_dates, buy_hold_value_over_time, label=f'Buy & Hold ({buy_hold_return:,.2f}%)', 
         color='blue', linewidth=2, linestyle='--')

ax2.axhline(y=initial_capital, color='gray', linestyle=':', label=f'Initial Capital (${initial_capital:,.2f})')
ax2.set_xlabel('Date')
ax2.set_ylabel('Portfolio Value (USD)')
ax2.set_title('Trading Strategy Performance Comparison')
ax2.legend()
ax2.grid(True, alpha=0.3)

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# FINAL METRICS & VISUALIZATION
# ============================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 8
#       5 print("="*60)
#       7 # 1. Print the Accuracy Score (which you already calculated)
# ----> 8 print(f"Directional Accuracy (using optimal threshold): {accuracy * 100:.4f}%")
#       9 print(f"ROC AUC Score: {roc_auc:.4f}")
#      11 # 2. Create the plots
#
# NameError: name 'accuracy' is not defined
